# %% [markdown]
# # Approach
# <!-- Describe your approach to solving the problem. -->
# 本题本质上是想要最多的峰值(一上一下)。局部最优在于：删除单调坡度上除了端点外的点，那么这个坡度有两个峰值(端点)！
# ![WeChatf4ddff1cf83c11c2484b0e1ca8a067eb.jpg](attachment:WeChatf4ddff1cf83c11c2484b0e1ca8a067eb.jpg)
#
# # Note
# 贪心的本质是选择每一阶段的局部最优，从而达到全局最优。刷题或者面试的时候，手动模拟一下感觉可以局部最优推出整体最优，而且想不到反例，那么就试一试贪心。
#
# # Code

# %%
# 贪心

# %%
# 动规
